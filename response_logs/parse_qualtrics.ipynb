# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
#df = pd.read_csv('../../DRAGN-Town Evaluation V3_December 12, 2022_15.10.tsv', sep='\t', encoding='utf-16')
df = pd.read_csv('./CLEANED_DRAGN-Town Evaluation V4_January 26, 2023_15.55.tsv', sep='\t')
df = df.astype('string')
print(df.keys())
misc = df.keys()[0:6]

gpt2 = df.keys()[6:86]
lrg = df.keys()[86:166]
mys = df.keys()[166:246]
temp = df.keys()[246:326]
wow = df.keys()[326:406]
misc2 = df.keys()[406:]
# Out:
# Index(['Q133', 'Q134', 'Native Language', 'Q135', 'Q102', 'Q136', 'Q1_1',
#        'Q1_2', 'Q1_3', 'Q1_4',
#        ...
#        'Q102_2', 'Q102_3', 'Q102_4', 'Q103_1', 'Q103_2', 'Q103_3', 'Q103_4',
#        'Q137', 'Q140', 'Q132'],
#       dtype='object', length=409)

# %%
print(df['Q133'].value_counts())
df['Q133'].value_counts().plot(kind='bar')
plt.show()
print()
print(df['Q134'].value_counts())
df['Q134'].value_counts().plot(kind='bar')
plt.show()
# Out:
# 18 - 24        200
# 25 - 34          4
# 35 - 44          1
# 75 or older      1
# 45 - 54          1
# Name: Q133, dtype: Int64
# Moderately familiar    62
# Very familiar          51
# Slightly familiar      40
# Extremely familiar     30
# Not familiar at all    23
# Name: Q134, dtype: Int64

# %%
print(gpt2[::4])
print(gpt2[1::4])
print(gpt2[2::4])
print(gpt2[3::4])
# Out:
# Index(['Q1_1', 'Q2_1', 'Q3_1', 'Q4_1', 'Q5_1', 'Q24_1', 'Q25_1', 'Q26_1',
#        'Q27_1', 'Q28_1', 'Q44_1', 'Q45_1', 'Q46_1', 'Q47_1', 'Q48_1', 'Q64_1',
#        'Q65_1', 'Q66_1', 'Q67_1', 'Q68_1'],
#       dtype='object')
# Index(['Q1_2', 'Q2_2', 'Q3_2', 'Q4_2', 'Q5_2', 'Q24_2', 'Q25_2', 'Q26_2',
#        'Q27_2', 'Q28_2', 'Q44_2', 'Q45_2', 'Q46_2', 'Q47_2', 'Q48_2', 'Q64_2',
#        'Q65_2', 'Q66_2', 'Q67_2', 'Q68_2'],
#       dtype='object')
# Index(['Q1_3', 'Q2_3', 'Q3_3', 'Q4_3', 'Q5_3', 'Q24_3', 'Q25_3', 'Q26_3',
#        'Q27_3', 'Q28_3', 'Q44_3', 'Q45_3', 'Q46_3', 'Q47_3', 'Q48_3', 'Q64_3',
#        'Q65_3', 'Q66_3', 'Q67_3', 'Q68_3'],
#       dtype='object')
# Index(['Q1_4', 'Q2_4', 'Q3_4', 'Q4_4', 'Q5_4', 'Q24_4', 'Q25_4', 'Q26_4',
#        'Q27_4', 'Q28_4', 'Q44_4', 'Q45_4', 'Q46_4', 'Q47_4', 'Q48_4', 'Q64_4',
#        'Q65_4', 'Q66_4', 'Q67_4', 'Q68_4'],
#       dtype='object')

# %% [markdown]
# GPT-2

# %%
#print(df['Q1_1'].value_counts())

q_lbls = ['_1', '_2', '_3', '_4']
gpt2_master_dict = {}
for i in range(4):
    mydict = {}
    for col in gpt2[i::4]:
        #print('here')
        #print(df[col].value_counts())
        for idx, lbl in enumerate(df[col].value_counts().index.tolist()):
            try:
                #print(df[['Q1_1']].value_counts())
                if lbl[0] == '7':
                    lbl = '7'
                elif lbl[0] == '6':
                    lbl = '6'
                elif lbl[0] == '5':
                    lbl = '5'
                elif lbl[0] == '4':
                    lbl = '4'
                elif lbl[0] == '3':
                    lbl = '3'
                elif lbl[0] == '2':
                    lbl = '2'
                elif lbl[0:2] == ' 1':
                    lbl = '1'
                mydict[lbl] += df[col].value_counts()[idx]
            except:
                if lbl[0] == '7':
                    lbl = '7'
                elif lbl[0] == '6':
                    lbl = '6'
                elif lbl[0] == '5':
                    lbl = '5'
                elif lbl[0] == '4':
                    lbl = '4'
                elif lbl[0] == '3':
                    lbl = '3'
                elif lbl[0] == '2':
                    lbl = '2'
                elif lbl[0:2] == ' 1':
                    lbl = '1'
                mydict[lbl] = 0
                mydict[lbl] += df[col].value_counts()[idx]

    print(mydict)
    gpt2_master_dict[q_lbls[i]] = mydict
#print(master_dict)
# Out:
# {'7': 107, '5': 71, '3': 51, '6': 95, '4': 31, '1': 11, '2': 13}
# {'3': 58, '5': 77, '7': 82, '6': 57, '4': 43, '2': 35, '1': 27}
# {'5': 102, '4': 59, '3': 37, '6': 96, '7': 66, '2': 14, '1': 5}
# {'5': 105, '6': 80, '4': 60, '3': 29, '2': 18, '7': 82, '1': 5}

# %% [markdown]
# large

# %%
q_lbls = ['_1', '_2', '_3', '_4']
large_master_dict = {}
for i in range(4):
    mydict = {}
    for col in lrg[i::4]:
        #print('here')
        #print(df[col].value_counts())
        for idx, lbl in enumerate(df[col].value_counts().index.tolist()):
            try:
                #print(df[['Q1_1']].value_counts())
                if lbl[0] == '7':
                    lbl = '7'
                elif lbl[0] == '6':
                    lbl = '6'
                elif lbl[0] == '5':
                    lbl = '5'
                elif lbl[0] == '4':
                    lbl = '4'
                elif lbl[0] == '3':
                    lbl = '3'
                elif lbl[0] == '2':
                    lbl = '2'
                elif lbl[0:2] == ' 1':
                    lbl = '1'
                mydict[lbl] += df[col].value_counts()[idx]
            except:
                if lbl[0] == '7':
                    lbl = '7'
                elif lbl[0] == '6':
                    lbl = '6'
                elif lbl[0] == '5':
                    lbl = '5'
                elif lbl[0] == '4':
                    lbl = '4'
                elif lbl[0] == '3':
                    lbl = '3'
                elif lbl[0] == '2':
                    lbl = '2'
                elif lbl[0:2] == ' 1':
                    lbl = '1'
                mydict[lbl] = 0
                mydict[lbl] += df[col].value_counts()[idx]

    print(mydict)
    large_master_dict[q_lbls[i]] = mydict
#print(master_dict)
# Out:
# {'7': 144, '4': 33, '5': 64, '6': 79, '3': 21, '1': 4, '2': 11}
# {'3': 31, '7': 121, '5': 54, '4': 41, '6': 83, '2': 16, '1': 10}
# {'4': 60, '6': 87, '3': 23, '7': 77, '5': 89, '1': 11, '2': 9}
# {'6': 84, '4': 56, '5': 68, '7': 95, '1': 12, '2': 18, '3': 23}

# %% [markdown]
# mys

# %%
q_lbls = ['_1', '_2', '_3', '_4']
mys_master_dict = {}
for i in range(4):
    mydict = {}
    for col in mys[i::4]:
        #print('here')
        #print(df[col].value_counts())
        for idx, lbl in enumerate(df[col].value_counts().index.tolist()):
            try:
                #print(df[['Q1_1']].value_counts())
                if lbl[0] == '7':
                    lbl = '7'
                elif lbl[0] == '6':
                    lbl = '6'
                elif lbl[0] == '5':
                    lbl = '5'
                elif lbl[0] == '4':
                    lbl = '4'
                elif lbl[0] == '3':
                    lbl = '3'
                elif lbl[0] == '2':
                    lbl = '2'
                elif lbl[0:2] == ' 1':
                    lbl = '1'
                mydict[lbl] += df[col].value_counts()[idx]
            except:
                if lbl[0] == '7':
                    lbl = '7'
                elif lbl[0] == '6':
                    lbl = '6'
                elif lbl[0] == '5':
                    lbl = '5'
                elif lbl[0] == '4':
                    lbl = '4'
                elif lbl[0] == '3':
                    lbl = '3'
                elif lbl[0] == '2':
                    lbl = '2'
                elif lbl[0:2] == ' 1':
                    lbl = '1'
                mydict[lbl] = 0
                mydict[lbl] += df[col].value_counts()[idx]

    print(mydict)
    mys_master_dict[q_lbls[i]] = mydict
#print(master_dict)
# Out:
# {'7': 107, '6': 69, '5': 71, '4': 51, '1': 9, '3': 47, '2': 18}
# {'5': 83, '7': 92, '6': 70, '2': 18, '3': 39, '4': 57, '1': 13}
# {'4': 70, '6': 84, '7': 81, '3': 27, '5': 102, '2': 8}
# {'7': 89, '4': 82, '5': 92, '6': 84, '2': 6, '3': 19}

# %% [markdown]
# template

# %%
q_lbls = ['_1', '_2', '_3', '_4']
temp_master_dict = {}
for i in range(4):
    mydict = {}
    for col in temp[i::4]:
        #print('here')
        #print(df[col].value_counts())
        for idx, lbl in enumerate(df[col].value_counts().index.tolist()):
            try:
                #print(df[['Q1_1']].value_counts())
                if lbl[0] == '7':
                    lbl = '7'
                elif lbl[0] == '6':
                    lbl = '6'
                elif lbl[0] == '5':
                    lbl = '5'
                elif lbl[0] == '4':
                    lbl = '4'
                elif lbl[0] == '3':
                    lbl = '3'
                elif lbl[0] == '2':
                    lbl = '2'
                elif lbl[0:2] == ' 1':
                    lbl = '1'
                mydict[lbl] += df[col].value_counts()[idx]
            except:
                if lbl[0] == '7':
                    lbl = '7'
                elif lbl[0] == '6':
                    lbl = '6'
                elif lbl[0] == '5':
                    lbl = '5'
                elif lbl[0] == '4':
                    lbl = '4'
                elif lbl[0] == '3':
                    lbl = '3'
                elif lbl[0] == '2':
                    lbl = '2'
                elif lbl[0:2] == ' 1':
                    lbl = '1'
                mydict[lbl] = 0
                mydict[lbl] += df[col].value_counts()[idx]

    print(mydict)
    temp_master_dict[q_lbls[i]] = mydict
#print(master_dict)
# Out:
# {'3': 79, '6': 53, '5': 67, '2': 48, '1': 47, '7': 33, '4': 37}
# {'2': 61, '1': 62, '3': 59, '4': 43, '6': 49, '7': 31, '5': 59}
# {'5': 106, '7': 41, '4': 72, '6': 40, '3': 55, '2': 29, '1': 21}
# {'5': 96, '4': 74, '7': 38, '6': 60, '3': 49, '2': 26, '1': 21}

# %% [markdown]
# wow

# %%
q_lbls = ['_1', '_2', '_3', '_4']
wow_master_dict = {}
for i in range(4):
    mydict = {}
    for col in wow[i::4]:
        #print('here')
        #print(df[col].value_counts())
        for idx, lbl in enumerate(df[col].value_counts().index.tolist()):
            try:
                #print(df[['Q1_1']].value_counts())
                if lbl[0] == '7':
                    lbl = '7'
                elif lbl[0] == '6':
                    lbl = '6'
                elif lbl[0] == '5':
                    lbl = '5'
                elif lbl[0] == '4':
                    lbl = '4'
                elif lbl[0] == '3':
                    lbl = '3'
                elif lbl[0] == '2':
                    lbl = '2'
                elif lbl[0:2] == ' 1':
                    lbl = '1'
                mydict[lbl] += df[col].value_counts()[idx]
            except:
                if lbl[0] == '7':
                    lbl = '7'
                elif lbl[0] == '6':
                    lbl = '6'
                elif lbl[0] == '5':
                    lbl = '5'
                elif lbl[0] == '4':
                    lbl = '4'
                elif lbl[0] == '3':
                    lbl = '3'
                elif lbl[0] == '2':
                    lbl = '2'
                elif lbl[0:2] == ' 1':
                    lbl = '1'
                mydict[lbl] = 0
                mydict[lbl] += df[col].value_counts()[idx]

    print(mydict)
    wow_master_dict[q_lbls[i]] = mydict
#print(master_dict)
# Out:
# {'7': 342, '6': 178, '5': 111, '4': 50, '3': 34, '2': 10, '1': 3}
# {'7': 308, '6': 177, '5': 125, '4': 57, '3': 47, '2': 10, '1': 4}
# {'6': 185, '7': 247, '5': 164, '4': 85, '2': 9, '3': 36, '1': 2}
# {'5': 129, '6': 206, '4': 82, '7': 262, '3': 34, '2': 14, '1': 1}

# %%
tk = '_4'
t_sum = sum([int(x) * y for x,y in gpt2_master_dict[tk].items()])
cnt = sum(gpt2_master_dict[tk].values()) # total
print(t_sum / cnt)
# Out:
# 5.137203166226913

# %%
n_lbls = ['1','2','3','4','5','6','7']
mylist = []
for q in q_lbls:
    temp = []
    t_sum = sum([int(x) * y for x,y in gpt2_master_dict[q].items()])
    cnt = sum(gpt2_master_dict[q].values()) # total
    temp.append(t_sum/cnt)

    t_sum = sum([int(x) * y for x,y in large_master_dict[q].items()])
    cnt = sum(large_master_dict[q].values()) # total
    temp.append(t_sum/cnt)

    t_sum = sum([int(x) * y for x,y in mys_master_dict[q].items()])
    cnt = sum(mys_master_dict[q].values()) # total
    temp.append(t_sum/cnt)

    t_sum = sum([int(x) * y for x,y in temp_master_dict[q].items()])
    cnt = sum(temp_master_dict[q].values()) # total
    temp.append(t_sum/cnt)

    t_sum = sum([int(x) * y for x,y in wow_master_dict[q].items()])
    cnt = sum(wow_master_dict[q].values()) # total
    temp.append(t_sum/cnt)

    mylist.append(temp)
print(mylist)
# Out:
# [[5.245382585751979, 5.682584269662922, 5.129032258064516, 3.879120879120879, 5.964285714285714], [4.601583113456464, 5.376404494382022, 5.03494623655914, 3.6785714285714284, 5.818681318681318], [5.087071240105541, 5.179775280898877, 5.263440860215054, 4.365384615384615, 5.668956043956044], [5.137203166226913, 5.196629213483146, 5.333333333333333, 4.456043956043956, 5.733516483516484]]

# %%
def shiftedColorMap(cmap, start=0, midpoint=0.5, stop=1.0, name='shiftedcmap'):
    '''
    Function to offset the "center" of a colormap. Useful for
    data with a negative min and positive max and you want the
    middle of the colormap's dynamic range to be at zero
    
    Input
    -----
      cmap : The matplotlib colormap to be altered
      start : Offset from lowest point in the colormap's range.
          Defaults to 0.0 (no lower ofset). Should be between
          0.0 and 1.0.
      midpoint : The new center of the colormap. Defaults to 
          0.5 (no shift). Should be between 0.0 and 1.0. In
          general, this should be  1 - vmax/(vmax + abs(vmin))
          For example if your data range from -15.0 to +5.0 and
          you want the center of the colormap at 0.0, `midpoint`
          should be set to  1 - 5/(5 + 15)) or 0.75
      stop : Offset from highets point in the colormap's range.
          Defaults to 1.0 (no upper ofset). Should be between
          0.0 and 1.0.
    '''
    cdict = {
        'red': [],
        'green': [],
        'blue': [],
        'alpha': []
    }
      
    # regular index to compute the colors
    reg_index = np.linspace(start, stop, 257)

    # shifted index to match the data
    shift_index = np.hstack([
        np.linspace(0.0, midpoint, 128, endpoint=False), 
        np.linspace(midpoint, 1.0, 129, endpoint=True)
    ])
    
    for ri, si in zip(reg_index, shift_index):
        r, g, b, a = cmap(ri)

        cdict['red'].append((si, r, r))
        cdict['green'].append((si, g, g))
        cdict['blue'].append((si, b, b))
        cdict['alpha'].append((si, a, a))
        
    newcmap = matplotlib.colors.LinearSegmentedColormap(name, cdict)
    plt.register_cmap(cmap=newcmap)

    return newcmap

# %%
ax = plt.figure(figsize=(8, 7), facecolor='white').add_subplot(111)

hatches = ''.join(h*len(q_lbls) for h in '-/O.\\')

orig_cmap = matplotlib.cm.Blues # The original colormap we want to work with!

# Define shifted and shrunk version of the cmap
#shifted_cmap = shiftedColorMap(orig_cmap, midpoint=0.75, name='shifted')
#shrunk_cmap = shiftedColorMap(orig_cmap, start=0.15, midpoint=0.65, stop=0.85, name='shrunk')

# avg_df.transpose().plot.bar(
#     title="Dialogue Quality By Model", 
#     ax=ax,
#     ylim=(0,7),
#     legend=True,
#     ylabel="Average Likert Score",
#     hatch=hatches,
#     cmap=shrunk_cmap
# )
#plt.bar(title="Dialogue Quality By Model",ax=ax, ylim=(0,7), legend=True, ylabel="Average Likert Score", hatch=hatches,cmap=shrunk_cmap)


barWidth = 0.15
#fig = plt.subplots(figsize=(14, 10))
br1 = range(len(q_lbls))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]
br5 = [x + barWidth for x in br4]

plt.bar(br1, [i[0] for i in mylist], width=barWidth, label='DRG-M', color=(0.1, 0.7, 0.7, 0.4))
plt.bar(br2, [i[1] for i in mylist], width=barWidth, label='DRG-L', color=(0.9, 0.7, 0.0, 0.3))
plt.bar(br3, [i[2] for i in mylist], width=barWidth, label='VS_MYS', color=(0.6, 0.3, 0.5, 0.4))
plt.bar(br4, [i[3] for i in mylist], width=barWidth, label='DRG-T', color=(1, 0.0, 0.0, 0.4))
plt.bar(br5, [i[4] for i in mylist], width=barWidth, label='WOW', color=(0.2, 0.4, 0.9, 0.4))

plt.xticks([r + barWidth for r in range(len(q_lbls))], ['Fluency', 'Coherence', 'Novelty', 'Creativity'])
#plt.set_cmap(shrunk_cmap)
plt.title("Dialogue Quality By Model")
plt.ylabel("Average Likert Score")

bars = ax.patches
print(f"len(bars): {len(bars)}")
print(f"len(hatches): {len(hatches)}")
for bar, hatch in zip(bars, hatches):
    print(bar, hatch)
    bar.set_hatch(hatch)

plt.rcParams.update({'font.size': 12})
plt.xticks(rotation=0)
leg = ax.legend(loc='best', bbox_to_anchor=(1,1), ncol=1, facecolor='white')

for text in leg.get_texts():
    text.set_color('black')

ax.set_facecolor('white')
ax.tick_params(axis='x', colors='black')
ax.tick_params(axis='y', colors='black')
ax.yaxis.label.set_color('black')
ax.xaxis.label.set_color('black')
ax.spines['bottom'].set_color('black')
ax.spines['top'].set_color('black') 
ax.spines['right'].set_color('black')
ax.spines['left'].set_color('black')
ax.title.set_color('black')

plt.savefig(fname="survey_visual", bbox_inches='tight')
# Out:
# len(bars): 20
# len(hatches): 20
# Rectangle(xy=(-0.075, 0), width=0.15, height=5.24538, angle=0) -
# Rectangle(xy=(0.925, 0), width=0.15, height=4.60158, angle=0) -
# Rectangle(xy=(1.925, 0), width=0.15, height=5.08707, angle=0) -
# Rectangle(xy=(2.925, 0), width=0.15, height=5.1372, angle=0) -
# Rectangle(xy=(0.075, 0), width=0.15, height=5.68258, angle=0) /
# Rectangle(xy=(1.075, 0), width=0.15, height=5.3764, angle=0) /
# Rectangle(xy=(2.075, 0), width=0.15, height=5.17978, angle=0) /
# Rectangle(xy=(3.075, 0), width=0.15, height=5.19663, angle=0) /
# Rectangle(xy=(0.225, 0), width=0.15, height=5.12903, angle=0) O
# Rectangle(xy=(1.225, 0), width=0.15, height=5.03495, angle=0) O
# Rectangle(xy=(2.225, 0), width=0.15, height=5.26344, angle=0) O
# Rectangle(xy=(3.225, 0), width=0.15, height=5.33333, angle=0) O
# Rectangle(xy=(0.375, 0), width=0.15, height=3.87912, angle=0) .
# Rectangle(xy=(1.375, 0), width=0.15, height=3.67857, angle=0) .
# ...
